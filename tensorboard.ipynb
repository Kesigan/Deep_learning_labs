# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install -c conda-forge tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'conda-forge'

# %%
conda install -c conda-forge scipy numpy matplotlib pandas statsmodels scikit-learn
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\kesig\anaconda3
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#     - scipy
#     - statsmodels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       h56e8100_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     libblas-3.9.0              |1_h8933c1f_netlib         193 KB  conda-forge
#     libcblas-3.9.0             |5_hd5c7e75_netlib          95 KB  conda-forge
#     liblapack-3.9.0            |5_hd5c7e75_netlib         2.7 MB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
# ...

# %%
pip install -c conda-forge tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'conda-forge'

# %%
conda install -c conda-forge tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\kesig\anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           3 KB
#     absl-py-2.0.0              |     pyhd8ed1ab_0         103 KB  conda-forge
#     aiohttp-3.8.1              |  py310he2412df_1         555 KB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     async-timeout-4.0.3        |     pyhd8ed1ab_0          11 KB  conda-forge
# ...

# %%
conda install keras
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\kesig\anaconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.12.12 |       haa95532_0         127 KB
#     certifi-2023.11.17         |  py310haa95532_0         159 KB
#     ------------------------------------------------------------
#                                            Total:         286 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2023.11.~ --> pkgs/main::ca-certificates-2023.12.12-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2023.11.1~ --> pkgs/main/win-64::certifi-2023.11.17-py310haa95532_0
#
#
#
# ...
#
# ...

# %%
import tensorflow as tf
# Out:
# C:\Users\kesig\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from tensorflow.python.summary.writer.writer import FileWriter # for viewing Tensor graph

# %%
# %load_ext tensorboard

# %%
x = tf.Variable(4, name='x')

# %%
y = tf.Variable(5, name='y')

# %%
f = x*x*y+y+2

# %%
init = tf.compat.v1.global_variables_initializer()

# %%
import tensorflow as tf

# Eager execution is enabled by default in TensorFlow 2.x, so there's no need for a session

# Initialize variables (if needed - not necessary in many cases in TF 2.x)
# init = tf.compat.v1.global_variables_initializer()  # If necessary in your code

# Your operations
result = f.numpy()  # Evaluate the tensor f (assuming f is a TensorFlow tensor)

print(result)

# Saving the graph in TensorFlow 2.x using tf.summary.FileWriter
# Create a summary writer
writer = tf.summary.create_file_writer('logs/train')

# Write the graph
with writer.as_default():
    tf.summary.trace_on(graph=True)
    # Your operations here
    tf.summary.trace_export(name="model_trace", step=0)

# Close the writer
writer.close()
# Out:
# 87

# %%
# %tensorboard --logdir logs/train
# Out:
#       <iframe id="tensorboard-frame-f94185aec7f3bbb3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f94185aec7f3bbb3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
